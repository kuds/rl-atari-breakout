# %% [markdown]
# <a href="https://colab.research.google.com/github/kuds/rl-atari-breakout/blob/main/%5BAtari%20Breakout%5D%20Single-Agent%20Reinforcement%20Learning%20PPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Atari Breakout] Single-Agent Reinforcement Learning PPO

# %% [markdown]
# ## Overview
#
# This notebook trains a [Proximal Policy Optimization](https://arxiv.org/abs/1707.06347) (PPO) agent on Atari Breakout
# (`ALE/Breakout-v5`) using [Stable Baselines3](https://stable-baselines3.readthedocs.io/).
#
# PPO is an on-policy, actor-critic algorithm:
#
# - the **actor** outputs a categorical distribution over Breakout's 4
#   discrete actions
# - the **critic** estimates the value `V(s)` used for advantages (GAE)
# - updates use a **clipped surrogate objective** so the policy never moves
#   too far in one step
#
# The pipeline:
#
# 1. Wrap the Atari env (FIRE-on-reset, frame-skip 4, grayscale 84x84,
#    4-frame stack, episodic life loss). 8 parallel envs feed the rollout.
# 2. Train the agent with `EvalCallback` periodically saving the best model
#    and `CheckpointCallback` snapshotting weights to disk.
# 3. Reload the best model, re-evaluate it on the eval env, record gameplay
#    video, plot the training curve, and print a stage summary.
#
# Hyperparameters mirror the [RL Zoo Atari PPO config](https://github.com/DLR-RM/rl-baselines3-zoo/blob/master/hyperparams/ppo.yml).

# %% [markdown]
# ## Setup
#
# Install the Atari + Stable Baselines3 stack and import everything
# the rest of the notebook needs.

# %%
# !pip install swig

# %%
# !pip install stable-baselines3

# %%
# !pip install gymnasium[atari] ale-py

# %%
import os
import csv
import time
import json
import platform
import torch
import shutil
import numpy
import stable_baselines3
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import VecVideoRecorder
from stable_baselines3.common.vec_env import VecTransposeImage
import stable_baselines3.common.atari_wrappers
import matplotlib.pyplot
import matplotlib
import ale_py
import gymnasium
from importlib.metadata import version
from datetime import datetime
import google.colab.drive

# %%
print(f"Python Version: {platform.python_version()}")
print(f"Torch Version: {version('torch')}")
print(f"Is Cuda Available: {torch.cuda.is_available()}")
print(f"Cuda Version: {torch.version.cuda}")
if torch.cuda.is_available(): print(f"GPU Device: {torch.cuda.get_device_name(0)}")
print(f"Gymnasium Version: {version('gymnasium')}")
print(f"Numpy Version: {version('numpy')}")
print(f"Scipy Version: {version('scipy')}")
print(f"Swig Version: {version('swig')}")
print(f"Stable Baselines3 Version: {version('stable_baselines3')}")
print(f"ALE Version: {version('ale_py')}")

# %% [markdown]
# ## Run configuration
#
# Name the algorithm and environment, mount Google Drive (so artifacts
# survive Colab session timeouts), and choose a log directory. The slug
# `env_slug` is the env name with `/` replaced by `-` so it is safe to use
# in filesystem paths.

# %%
rl_type = "PPO"
env_str = "ALE/Breakout-v5"
# ALE env IDs contain a slash; sanitize for filesystem paths.
env_slug = env_str.replace("/", "-")
name_prefix = f"{env_slug}_{rl_type}".lower()
log_dir = ""
parent_path = ""
use_google_drive = True
if use_google_drive:
    parent_path = "/content/gdrive"
    google.colab.drive.mount(parent_path, force_remount=True)
    log_dir = "{}/MyDrive/Finding Theta/rl-atari-breakout/logs/{}/{}".format(parent_path,
                                                       env_slug,
                                                       rl_type)
else:
    log_dir = "/content/logs/{}/{}".format(env_slug, rl_type)

# %% [markdown]
# ## Environment wrapper configuration
#
# ALE's `-v5` envs ship with their own frame-skip and sticky actions.
# We disable both and let SB3's `AtariWrapper` handle frame-skip itself,
# so we never get double-frameskip.

# %%
# Wrapper / env kwargs for ALE/Breakout-v5.
#
# v5 ships with frameskip=4 and sticky actions (repeat_action_probability=0.25).
# We disable both at the env level and let stable-baselines3's AtariWrapper
# do frame skipping (frame_skip=4), so we don't double-frameskip.
#
# https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/
# https://stable-baselines3.readthedocs.io/en/master/common/atari_wrappers.html

env_kwargs = {
    "render_mode": "rgb_array",
    "frameskip": 1,
    "repeat_action_probability": 0.0,
}
wrapper_kwargs = {"frame_skip": 4}
# In-training eval env: adds noop_max for random no-op starts. Keeps
# AtariWrapper defaults (terminal_on_life_loss=True, clip_reward=True),
# which give EvalCallback a denser per-life signal for picking "best".
eval_wrapper_kwargs = {**wrapper_kwargs, "noop_max": 30}
# Final post-training eval / video env: real game, real score.
# Disables life-loss termination and reward clipping so the reported
# numbers are unclipped per-game scores comparable to standard Atari
# baselines, and the video covers a full 5-life game.
final_eval_wrapper_kwargs = {
    **eval_wrapper_kwargs,
    "terminal_on_life_loss": False,
    "clip_reward": False,
}

# %% [markdown]
# ## Final-eval helper: FIRE-on-life-loss wrapper
#
# `AtariWrapper`'s `FireResetEnv` only presses FIRE on `reset()`. During
# training that's fine because `terminal_on_life_loss=True` makes every
# life-loss trigger a reset. At final eval we set
# `terminal_on_life_loss=False` so episodes count full 5-life games — but
# then the ball is never re-launched after the first life and the agent
# just times out at `max_episode_steps=108000`, dragging the reported
# score well below per-life training numbers.
#
# `FireOnLifeLostEnv` wraps the env *after* `AtariWrapper` and presses
# FIRE whenever `ale.lives()` drops, so the ball relaunches and the agent
# gets to play out the remaining lives. We use this only on the final
# eval env so training behavior is unchanged.

# %%
class FireOnLifeLostEnv(gymnasium.Wrapper):
    """Press FIRE after each life loss so the ball relaunches.

    Used on the final-eval env (terminal_on_life_loss=False) where
    AtariWrapper's FireResetEnv would otherwise only fire at game reset,
    causing the agent to stall after the first life.
    """

    def __init__(self, env):
        super().__init__(env)
        self._lives = 0

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self._lives = self.env.unwrapped.ale.lives()
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        new_lives = self.env.unwrapped.ale.lives()
        if (
            new_lives < self._lives
            and new_lives > 0
            and not (terminated or truncated)
        ):
            obs, fire_reward, terminated, truncated, info = self.env.step(1)
            reward = reward + fire_reward
            new_lives = self.env.unwrapped.ale.lives()
        self._lives = new_lives
        return obs, reward, terminated, truncated, info


def _atari_wrapper_with_fire_relaunch(env, **kwargs):
    """AtariWrapper composed with FireOnLifeLostEnv, for make_vec_env."""
    env = stable_baselines3.common.atari_wrappers.AtariWrapper(env, **kwargs)
    env = FireOnLifeLostEnv(env)
    return env

# %% [markdown]
# ## Per-run output folder
#
# Each training job lives in its own timestamped subdirectory under
# `training jobs/`. That keeps reruns from clobbering each other and
# makes it easy to compare runs later.

# %%
training_data_path = os.path.join(log_dir, "training jobs")
time_folder = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
model_folder_path = os.path.join(log_dir, "training jobs", time_folder)

# %%
#Create Folders
os.makedirs(log_dir, exist_ok=True)
os.makedirs(training_data_path, exist_ok=True)
os.makedirs(model_folder_path, exist_ok=True)

# %% [markdown]
# ## Inspect the environment
#
# Quick sanity check: print the observation and action spaces of both
# the wrapped (frame-stacked, grayscale) env and the raw `gymnasium`
# env, so we know what shape the network will consume.

# %%
env = gymnasium.make(env_str)
print("Observation Space Size: ", env.observation_space.shape)
print('Actions Space: ', env.action_space)
env.close()

# %%
env = make_atari_env(env_str,
                     n_envs=1,
                     seed=0,
                     env_kwargs=env_kwargs,
                     wrapper_kwargs=wrapper_kwargs)
print("Observation Space Size: ", env.observation_space.shape)
print('Actions Space: ', env.action_space)
env.close()

# %% [markdown]
# ## Hyperparameters
#
# Values mirror the RL Zoo's tuned Atari config (linked in the cell
# comment). The cadence knobs (`eval_freq`, `checkpoint_freq`,
# `video_freq`) and `n_eval_episodes` are split into separate fields so
# you can tune evaluation, checkpointing, and video cadence independently.

# %%
# Use Hyperparameters from RL Zoo
hyperparams = {
    "env_str": env_str,
    "rl_type": rl_type,
    "eval_freq": 50_000,
    "checkpoint_freq": 250_000,
    "video_freq": 250_000,
    "n_eval_episodes": 30,
    "total_timesteps": 7_500_000,
    "clip_range": 0.1,
    "learning_rate": 2.5e-4,
    "n_steps": 128,
    "n_epochs": 4,
    "n_envs": 8,
    "batch_size": 256,
    "ent_coef": 0.01,
    "vf_coef": 0.5,
}

# https://github.com/DLR-RM/rl-baselines3-zoo/blob/master/hyperparams/ppo.yml
# atari:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_envs: 8
#   n_steps: 128
#   n_epochs: 4
#   batch_size: 256
#   n_timesteps: !!float 1e7
#   learning_rate: lin_2.5e-4
#   clip_range: lin_0.1
#   vf_coef: 0.5
#   ent_coef: 0.01

# %% [markdown]
# ### Persist the run's parameters
#
# Dump every knob into `parameters.json` next to the model. Anytime you
# revisit a run from disk you can read this file to know exactly how it
# was configured.

# %%
# Capture the runtime device so the config file records what hardware the
# run used (Colab L4 vs. T4 vs. CPU, etc.).
gpu_info = {
    "torch_version": torch.__version__,
    "cuda_available": torch.cuda.is_available(),
    "cuda_version": torch.version.cuda,
    "device_count": torch.cuda.device_count(),
    "device_name": (
        torch.cuda.get_device_name(0) if torch.cuda.is_available() else None
    ),
    "device_capability": (
        list(torch.cuda.get_device_capability(0))
        if torch.cuda.is_available()
        else None
    ),
}

with open(os.path.join(model_folder_path, 'config.json'), 'w') as fp:
    config_obj = {"hyperparams": hyperparams,
                  "env_kwargs": env_kwargs,
                  "wrapper_kwargs": wrapper_kwargs,
                  "eval_wrapper_kwargs": eval_wrapper_kwargs,
                  "final_eval_wrapper_kwargs": final_eval_wrapper_kwargs,
                  "gpu": gpu_info}
    json.dump(config_obj, fp, indent=4)

# %% [markdown]
# ## Custom callback: periodic gameplay video
#
# SB3 ships an `EvalCallback` and a `CheckpointCallback`, but no
# built-in callback for periodically recording gameplay videos during
# training. This subclass of `BaseCallback` rolls a fresh eval env
# every `save_freq` steps, runs the *current* policy for `video_length`
# frames, and dumps the result as an mp4. Watching these in order is a
# fast qualitative check on whether the agent is actually learning.

# %%
class VideoRecordCallback(BaseCallback):
    def __init__(
        self,
        save_path: str,
        video_length: int,
        save_freq: int = 5_000,
        name_prefix: str ="rl_model",
        verbose: int = 0):

        super().__init__(verbose)
        self.save_freq = save_freq
        self.video_length = video_length
        self.save_path = save_path
        self.name_prefix = name_prefix
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseAlgorithm
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env # type: VecEnv
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # num_timesteps = n_envs * n times env.step() was called
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = {}  # type: Dict[str, Any]
        # self.globals = {}  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger # type: stable_baselines3.common.logger.Logger
        # Sometimes, for event callback, it is useful
        # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_step(self) -> bool:
        if self.n_calls % self.save_freq == 0:

          name_prefix = f"{self.name_prefix}_{self.num_timesteps}"

          # Record video of the best model playing Atari's Environment
          rec_val = make_atari_env(
              env_str,
              n_envs=1,
              seed=1,
              env_kwargs=env_kwargs,
              wrapper_kwargs=eval_wrapper_kwargs)
          rec_val = VecFrameStack(rec_val, n_stack=4)
          rec_val = VecTransposeImage(rec_val)
          rec_val = VecVideoRecorder(rec_val,
                                    self.save_path,
                                    video_length=self.video_length,
                                    record_video_trigger=lambda x: x == 0,
                                    name_prefix=name_prefix)

          obs = rec_val.reset()
          for _ in range(self.video_length):
              action, _states = self.model.predict(obs)
              obs, rewards, dones, info = rec_val.step(action)
              rec_val.render()
              if dones:
                break

          rec_val.close()
        return True

# %% [markdown]
# ## Build the training and evaluation environments
#
# Two separate envs: the **training env** (with `monitor_dir` for SB3 to
# log episode rewards) and a fresh **evaluation env** with a different
# seed and a `noop_max=30` random-no-op start, so eval is independent of
# training and isn't a memorized trajectory.
#
# `VecFrameStack(n_stack=4)` stacks 4 consecutive frames so the network
# sees motion (essential for Breakout — a single frame can't tell you
# which way the ball is moving). `VecTransposeImage` converts to channels-first
# for PyTorch.

# %%
# Create the Training Atari's Breakout environment with appropriate wrappers
env = make_atari_env(env_str,
                     n_envs=hyperparams["n_envs"],
                     seed=0,
                     monitor_dir=os.path.join(model_folder_path, "monitor"),
                     env_kwargs=env_kwargs,
                     wrapper_kwargs=wrapper_kwargs)
env = VecFrameStack(env, n_stack=4)
env = VecTransposeImage(env)

# Create the Evaluation Atari's Breakout environment with appropriate wrappers
env_val = make_atari_env(env_str,
                         n_envs=1,
                         seed=1,
                         env_kwargs=env_kwargs,
                         wrapper_kwargs=eval_wrapper_kwargs)
env_val = VecFrameStack(env_val, n_stack=4)
env_val = VecTransposeImage(env_val)

# %% [markdown]
# ## Callbacks
#
# Three callbacks run during training:
#
# - **`EvalCallback`** — rolls the current policy on the eval env every
#   `eval_freq` steps and saves the best-so-far model to
#   `best_model.zip`. Setting `eval_freq` too low can destabilize
#   learning since the eval env interrupts training.
# - **`CheckpointCallback`** — periodic snapshots so you can inspect
#   intermediate weights or resume from a crash.
# - **`VideoRecordCallback`** — our custom callback above.

# %%
# Create Callbacks
# Create Evaluation Callback
eval_callback = EvalCallback(
    env_val,
    best_model_save_path=model_folder_path,
    log_path=model_folder_path,
    eval_freq=hyperparams["eval_freq"],
    render=False,
    deterministic=True,
    n_eval_episodes=hyperparams["n_eval_episodes"])

# Create Checkpoint Callback
checkpoint_callback = CheckpointCallback(
    save_freq=hyperparams["checkpoint_freq"],
    save_path=os.path.join(model_folder_path, "checkpoints"),
    name_prefix=name_prefix,
    save_replay_buffer=False,
    save_vecnormalize=False,
)

video_record_callback = VideoRecordCallback(
    save_path=os.path.join(model_folder_path, "videos"),
    video_length=2_500,
    save_freq=hyperparams["video_freq"],
    name_prefix=name_prefix)

# Create the callback list
callbackList = CallbackList([checkpoint_callback,
                             video_record_callback,
                             eval_callback])

# %% [markdown]
# ## Train the agent
#
# This is the main training loop. With the default config it will run
# for `total_timesteps` interactions; the timing wrapper around
# `model.learn()` records `training_duration_seconds` for the stage
# summary at the end. The trained weights are saved as `final_model.zip`
# (in addition to the `best_model.zip` produced by `EvalCallback`).

# %%
# Initialize PPO
model = PPO('CnnPolicy',
            env,
            verbose=0,
            batch_size=hyperparams["batch_size"],
            learning_rate=hyperparams["learning_rate"],
            clip_range=hyperparams["clip_range"],
            n_steps=hyperparams["n_steps"],
            n_epochs=hyperparams["n_epochs"],
            tensorboard_log=os.path.join(log_dir, "tensorboard"))

# Train the model
training_start_time = time.time()
model.learn(total_timesteps=hyperparams["total_timesteps"],
            progress_bar=False,
            callback=callbackList)
training_end_time = time.time()
training_duration_seconds = training_end_time - training_start_time

# Save the trained model
model.save(os.path.join(model_folder_path, "final_model"))

env.close()
env_val.close()

# %% [markdown]
# ### (Optional) Resume from a previous run
#
# If the training cell crashed or timed out, uncomment this cell to
# pick the most recent `training jobs/` folder and continue from
# there instead of training from scratch.

# %%
# # Get model path from last training job (uncomment if training job interrupted)
# # List all entries in the directory
# entries = os.listdir(training_data_path)

# # Filter out only directories
# folders = [entry for entry in entries if os.path.isdir(os.path.join(training_data_path, entry))]

# # Sort the folders alphabetically
# folders.sort()

# # Get the last folder
# model_folder_path = os.path.join(training_data_path, folders[-1])
# print(model_folder_path)

# %% [markdown]
# ## Elevate best model and record playback
#
# Load `best_model.zip` (the best checkpoint saved by `EvalCallback`),
# re-evaluate it on the eval env to get a clean reward number, log a
# row into the cross-run `best_model_metrics.csv`, and record a
# longer gameplay video.

# %%
# Build a final-eval env with terminal_on_life_loss=False and clip_reward=False
# so reported scores are unclipped and counted per full 5-life game (comparable
# to standard Atari baselines), and the recorded video covers a full game
# rather than just the first life.
# make_atari_env hard-codes wrapper_class=AtariWrapper, so we go through
# make_vec_env to inject FireOnLifeLostEnv after AtariWrapper. This relaunches
# the ball on each life loss, fixing the eval-only timeout where the agent
# would otherwise stall after losing the first life and run out the 108000
# step limit.
env_val = make_vec_env(env_str,
                       n_envs=1,
                       seed=1,
                       env_kwargs=env_kwargs,
                       wrapper_class=_atari_wrapper_with_fire_relaunch,
                       wrapper_kwargs=final_eval_wrapper_kwargs)
env_val = VecFrameStack(env_val, n_stack=4)
env_val = VecTransposeImage(env_val)

# Load the best model
best_model_path = os.path.join(model_folder_path, "best_model")
best_model = PPO.load(best_model_path, env=env_val)

episode_rewards, episode_lengths = evaluate_policy(
    best_model,
    env_val,
    n_eval_episodes=hyperparams["n_eval_episodes"],
    deterministic=True,
    return_episode_rewards=True)
mean_reward = float(numpy.mean(episode_rewards))
std_reward = float(numpy.std(episode_rewards))
mean_ep_length = float(numpy.mean(episode_lengths))
std_ep_length = float(numpy.std(episode_lengths))
print(f"Best Model - Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")

best_metrics_path = os.path.join(log_dir, "best_model_metrics.csv")

# Create Best Model Metrics file if not there
if(not os.path.isfile(best_metrics_path)):
  with open(best_metrics_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["run_date",
                     "batch_size",
                     "ent_coef",
                     "learning_rate",
                     "num_timesteps",
                     "mean_reward",
                     "std_reward",
                     "n_steps",
                     "n_envs",
                     "gamma",
                     "gae_lambda",
                     "clip_range_vf",
                     "n_epochs"])

new_data = [os.path.basename(os.path.normpath(model_folder_path)),
            best_model.batch_size,
            best_model.ent_coef,
            best_model.learning_rate,
            best_model.num_timesteps,
            mean_reward,
            std_reward,
            best_model.n_steps,
            best_model.n_envs,
            best_model.gamma,
            best_model.gae_lambda,
            best_model.clip_range_vf,
            best_model.n_epochs]

with open(best_metrics_path, 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(new_data)

# Record video of the best model playing Atari's Breakout. With
# terminal_on_life_loss=False the env runs the full 5-life game, so we
# let video_length bound the recording instead of breaking after the
# first life. deterministic=True matches the eval above.
best_model_file_name = "best_model_{}".format(name_prefix)
rec_val = VecVideoRecorder(env_val,
                           os.path.join(model_folder_path, "videos"),
                           video_length=5_000,
                           record_video_trigger=lambda x: x == 0,
                           name_prefix=best_model_file_name)

obs = rec_val.reset()
for _ in range(5_000):
    action, _states = best_model.predict(obs, deterministic=True)
    obs, rewards, dones, info = rec_val.step(action)
    if dones[0]:
        obs = rec_val.reset()

env_val.close()
rec_val.close()

# %%
# Print Model
print(best_model.policy)

# %% [markdown]
# ## Performance plot
#
# `EvalCallback` writes its eval results to `evaluations.npz` (timesteps
# and per-episode returns at each eval point). Plotting mean +/- std over
# time gives a quick view of how reward evolved during training.

# %%
# Load the evaluations.npz file
data = numpy.load(os.path.join(model_folder_path, "evaluations.npz"))

# Extract the relevant data
timesteps = data['timesteps']
results = data['results']

# Calculate the mean and standard deviation of the results
mean_results = numpy.mean(results, axis=1)
std_results = numpy.std(results, axis=1)

# Plot the results
matplotlib.pyplot.figure()
matplotlib.pyplot.plot(timesteps, mean_results)
matplotlib.pyplot.fill_between(timesteps,
                               mean_results - std_results,
                               mean_results + std_results,
                               alpha=0.3)

matplotlib.pyplot.xlabel('Timesteps')
matplotlib.pyplot.ylabel('Mean Reward')
matplotlib.pyplot.title(f"{rl_type} Performance on {env_str}")
matplotlib.pyplot.savefig(os.path.join(model_folder_path, f"{rl_type}_{env_slug}_performance.png"))
matplotlib.pyplot.show()

# %% [markdown]
# ## Stage summary
#
# A single self-contained block summarizing the run: environment,
# algorithm, total timesteps, wall-clock duration, eval reward, and
# average episode length on the eval env. Useful for pasting into a
# logbook or PR description.

# %%
# Stage Summary
def _format_duration(seconds):
    seconds = int(round(seconds))
    hours, remainder = divmod(seconds, 3600)
    minutes, secs = divmod(remainder, 60)
    if hours:
        return f"{hours}h {minutes}m {secs}s"
    if minutes:
        return f"{minutes}m {secs}s"
    return f"{secs}s"


try:
    _duration_str = _format_duration(training_duration_seconds)
except NameError:
    _duration_str = "N/A (training cell not run in this session)"

_lines = [
    f"Atari Breakout: {rl_type} Training Summary",
    "=" * 50,
    "",
    f"Environment:    {env_str}",
    f"Algorithm:      {rl_type}",
    f"Date:           {time_folder}",
    f"Timesteps:      {hyperparams['total_timesteps']:,}",
    f"Duration:       {_duration_str}",
    f"Eval reward:    {mean_reward:.2f} +/- {std_reward:.2f}",
]
try:
    _lines.append(
        f"Avg ep length:  {mean_ep_length:.1f} +/- {std_ep_length:.1f} steps"
    )
except NameError:
    pass
_lines.append(f"Best model:     {best_model_path}.zip")

summary_text = "\n".join(_lines)
print(summary_text)

summary_path = os.path.join(model_folder_path, "stage_summary.txt")
with open(summary_path, "w") as f:
    f.write(summary_text + "\n")
print(f"\nSaved summary -> {summary_path}")

# %% [markdown]
# ## Save notebook with results
#
# Dump the executed notebook (with all cell outputs) into the run's
# folder so the saved artifacts include a record of exactly what was
# run and what it produced.

# %%
# Create version execution
notebook_name = "notebook.ipynb"
# %notebook -e $notebook_name

# %%
source_file = os.path.join(notebook_name)
destination_file = os.path.join(model_folder_path, notebook_name)

try:
    shutil.copyfile(notebook_name, destination_file)
    print(f"File '{source_file}' copied to '{destination_file}' successfully.")
except FileNotFoundError:
    print(f"Error: Source file '{source_file}' not found.")
except shutil.SameFileError:
    print(f"Error: Source and destination are the same file.")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ## Cleanup (Colab)
#
# Release the Colab runtime when training is finished, to avoid
# burning compute hours on an idle session. No-op when running locally.

# %%
# Disconnect the Colab runtime at the end of the notebook to save compute.
# No-op when running locally.
try:
    from google.colab import runtime as _colab_runtime
except ImportError:
    pass
else:
    import time
    print("Notebook finished. Disconnecting runtime in 5 seconds...")
    time.sleep(5)
    _colab_runtime.unassign()
