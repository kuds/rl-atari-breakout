# %% [markdown]
# <a href="https://colab.research.google.com/github/kuds/rl-atari-breakout/blob/main/%5BAtari%20Breakout%5D%20Single-Agent%20Reinforcement%20Learning%20PPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Atari Breakout] Single-Agent Reinforcement Learning PPO

# %%
# !pip install swig
# Out:
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.3.0)

# %%
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (3.0.2)

# %%
# !pip install gymnasium[atari] ale-py
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)

# %%
import os
import csv
import time
import json
import platform
import torch
import numpy
import stable_baselines3
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import VecVideoRecorder
from stable_baselines3.common.vec_env import VecTransposeImage
import matplotlib.pyplot
import matplotlib
import ale_py
import gymnasium
from importlib.metadata import version
from datetime import datetime
import google.colab.drive

# %%
print(f"Python Version: {platform.python_version()}")
print(f"Torch Version: {version('torch')}")
print(f"Is Cuda Available: {torch.cuda.is_available()}")
print(f"Cuda Version: {torch.version.cuda}")
print(f"Gymnasium Version: {version('gymnasium')}")
print(f"Numpy Version: {version('numpy')}")
print(f"Stable Baselines3 Version: {version('stable_baselines3')}")
print(f"ALE Version: {version('ale_py')}")
# Out:
# Python Version: 3.10.12
# Torch Version: 2.5.1+cu121
# Is Cuda Available: True
# Cuda Version: 12.1
# Gymnasium Version: 1.0.0
# Numpy Version: 1.26.4
# Stable Baselines3 Version: 2.4.0
# ALE Version: 0.10.1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
gdrive_path = "/content/gdrive"
google.colab.drive.mount(gdrive_path, force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
rl_type = "PPO"
env_str =  "BreakoutNoFrameskip-v4" #"ALE/Pong-v5"
name_prefix = "atari_breakout_ppo"
log_dir = "{}/MyDrive/Finding Theta/logs/{}/{}".format(gdrive_path,
                                                       env_str,
                                                       rl_type)
training_data_path = os.path.join(log_dir, "training jobs")
time_folder = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
model_folder_path = os.path.join(log_dir, "training jobs", time_folder)

# %%
#Create Folders
os.makedirs(log_dir, exist_ok=True)
os.makedirs(training_data_path, exist_ok=True)
os.makedirs(model_folder_path, exist_ok=True)

# %%
env = make_atari_env(env_str, n_envs=1, seed=0)
print("Observation Space Size: ", env.observation_space.shape)
print('Actions Space: ', env.action_space)
env.close()
# Out:
# Observation Space Size:  (84, 84, 1)
# Actions Space:  Discrete(4)

# %%
env = gymnasium.make(env_str)
print("Observation Space Size: ", env.observation_space.shape)
print('Actions Space: ', env.action_space)
env.close()
# Out:
# Observation Space Size:  (210, 160, 3)
# Actions Space:  Discrete(4)

# %%
# Use Hyperparameters from RL Zoo
hyperparams = {
    "env_str": env_str,
    "rl_type": rl_type,
    "eval_freq": 25_000,
    "total_timesteps": 250_000,
    "clip_range": 0.1,
    "learning_rate": 2.5e-4,
    "n_steps": 128,
    "n_epochs": 4,
    "n_envs": 8,
    "batch_size": 256,
    "ent_coef": 0.01,
    "vf_coef": 0.5,
}

# https://github.com/DLR-RM/rl-baselines3-zoo/blob/master/hyperparams/ppo.yml
# atari:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_envs: 8
#   n_steps: 128
#   n_epochs: 4
#   batch_size: 256
#   n_timesteps: !!float 1e7
#   learning_rate: lin_2.5e-4
#   clip_range: lin_0.1
#   vf_coef: 0.5
#   ent_coef: 0.01

# %%
# Evaluation Environment Wrapper Arguments
# Disable Frame Skipping
# Disable Noop Max
# https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/
# https://stable-baselines3.readthedocs.io/en/master/common/atari_wrappers.html

# Training Aruguments
env_wrap_args = {"frame_skip": 4}
env_kwargs = {"render_mode": "rgb_array"}

# Evaluation Aruguments
env_val_wrap_args = {"frame_skip": 4, "noop_max": 30}
env_val_kwargs = {"render_mode": "rgb_array"}

if(env_str == "ALE/Pong-v5"):
  env_wrap_args["frame_skip"] = 0
  env_val_kwargs["frameskip"] = 32
  env_val_kwargs["repeat_action_probability"] = 0.0

# %%
with open(os.path.join(model_folder_path, 'parameters.json'), 'w') as fp:
    parameters = {"hyperparams": hyperparams,
                  "env_wrap_args": env_wrap_args,
                  "env_kwargs": env_kwargs,
                  "env_val_wrap_args": env_val_wrap_args,
                  "env_val_kwargs": env_val_kwargs}
    json.dump(parameters, fp, indent=4)

# %%
class VideoRecordCallback(BaseCallback):
    def __init__(
        self,
        save_path: str,
        video_length: int,
        save_freq: int = 5_000,
        name_prefix: str ="rl_model",
        verbose: int = 0):

        super().__init__(verbose)
        self.save_freq = save_freq
        self.video_length = video_length
        self.save_path = save_path
        self.name_prefix = name_prefix
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseAlgorithm
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env # type: VecEnv
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # num_timesteps = n_envs * n times env.step() was called
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = {}  # type: Dict[str, Any]
        # self.globals = {}  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger # type: stable_baselines3.common.logger.Logger
        # Sometimes, for event callback, it is useful
        # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_step(self) -> bool:
        if self.n_calls % self.save_freq == 0:

          name_prefix = f"{self.name_prefix}_{self.num_timesteps}"

          # Record video of the best model playing Atari's Environment
          rec_val = make_atari_env(
              env_str,
              n_envs=1,
              seed=1)
          rec_val = VecFrameStack(rec_val, n_stack=4)
          rec_val = VecTransposeImage(rec_val)
          rec_val = VecVideoRecorder(rec_val,
                                    self.save_path,
                                    video_length=self.video_length,
                                    record_video_trigger=lambda x: x == 0,
                                    name_prefix=name_prefix)

          obs = rec_val.reset()
          for _ in range(self.video_length):
              action, _states = self.model.predict(obs)
              obs, rewards, dones, info = rec_val.step(action)
              rec_val.render()
              if dones:
                break

          rec_val.close()
        return True

# %%
# Create the Training Atari's Pong environment with appropriate wrappers
env = make_atari_env(env_str,
                     n_envs=hyperparams["n_envs"],
                     seed=0,
                     monitor_dir=os.path.join(model_folder_path, "monitor"))
env = VecFrameStack(env, n_stack=4)
env = VecTransposeImage(env)

# Create the Evaluation Atari's Pong environment with appropriate wrappers
env_val = make_atari_env(env_str,
                         n_envs=1,
                         seed=1)
env_val = VecFrameStack(env_val, n_stack=4)
env_val = VecTransposeImage(env_val)

# %%
# Create Callbacks
# Create Evaluation Callback
eval_callback = EvalCallback(
    env_val,
    best_model_save_path=model_folder_path,
    log_path=model_folder_path,
    eval_freq=hyperparams["eval_freq"],
    render=False,
    deterministic=True,
    n_eval_episodes=5)

# Create Checkpoint Callback
checkpoint_callback = CheckpointCallback(
    save_freq=hyperparams["eval_freq"],
    save_path=os.path.join(model_folder_path, "checkpoints"),
    name_prefix=name_prefix,
    save_replay_buffer=False,
    save_vecnormalize=False,
)

video_record_callback = VideoRecordCallback(
    save_path=os.path.join(model_folder_path, "videos"),
    video_length=2_500,
    save_freq=hyperparams["eval_freq"],
    name_prefix=name_prefix)

# Create the callback list
callbackList = CallbackList([checkpoint_callback,
                             video_record_callback,
                             eval_callback])

# %%
# Initialize PPO
model = PPO('CnnPolicy',
            env,
            verbose=1,
            batch_size=hyperparams["batch_size"],
            learning_rate=hyperparams["learning_rate"],
            clip_range=hyperparams["clip_range"],
            n_steps=hyperparams["n_steps"],
            n_epochs=hyperparams["n_epochs"],
            tensorboard_log=os.path.join(log_dir, "tensorboard"))

# Train the model
model.learn(total_timesteps=hyperparams["total_timesteps"],
            progress_bar=False,
            callback=callbackList)

# Save the trained model
model.save(os.path.join(model_folder_path, "final_model"))

env.close()
env_val.close()
# Out:
# Using cuda device
# Logging to /content/gdrive/MyDrive/Finding Theta/logs/BreakoutNoFrameskip-v4/PPO/tensorboard/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 176      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 692          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0018703698 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00111      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0372       |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.283        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 762          |
# |    ep_rew_mean          | 1.43         |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0006168244 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0513       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0333       |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000881    |
# |    value_loss           | 0.0705       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 752          |
# |    ep_rew_mean          | 1.4          |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0010423709 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0341       |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.000866    |
# |    value_loss           | 0.0649       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 757         |
# |    ep_rew_mean          | 1.42        |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.001534142 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0248      |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00042    |
# |    value_loss           | 0.063       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 1.33         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 6            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0026488632 |
# |    clip_fraction        | 0.071        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.299        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.019        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 0.0632       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 1.49         |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0021129788 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0258       |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 0.06         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 786           |
# |    ep_rew_mean          | 1.62          |
# | time/                   |               |
# |    fps                  | 364           |
# |    iterations           | 8             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00056432525 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.445         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0189        |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.000677     |
# |    value_loss           | 0.0537        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | 1.52         |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0006283708 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0347       |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.000553    |
# |    value_loss           | 0.0726       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 763          |
# |    ep_rew_mean          | 1.48         |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0032278874 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.568        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0205       |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 0.0524       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 785           |
# |    ep_rew_mean          | 1.6           |
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 11            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00035963487 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.421         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0345        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 0.000236      |
# |    value_loss           | 0.0747        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 800           |
# |    ep_rew_mean          | 1.72          |
# | time/                   |               |
# |    fps                  | 386           |
# |    iterations           | 12            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00077670114 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.577         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0231        |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.00069      |
# |    value_loss           | 0.0665        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.003207568 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0234      |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.000628   |
# |    value_loss           | 0.0533      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 820           |
# |    ep_rew_mean          | 1.8           |
# | time/                   |               |
# |    fps                  | 400           |
# |    iterations           | 14            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00097184867 |
# |    clip_fraction        | 0.19          |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 0.689         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0183        |
# |    n_updates            | 52            |
# |    policy_gradient_loss | -0.000477     |
# |    value_loss           | 0.0427        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 808          |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 15           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0006977113 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0212       |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.000523    |
# |    value_loss           | 0.0499       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 803          |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 16           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0018328209 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00881      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 0.0355       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 802          |
# |    ep_rew_mean          | 1.72         |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 17           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0031711294 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0174       |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 0.0304       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | 1.62         |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 18           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0013855596 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00543      |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.000531    |
# |    value_loss           | 0.0214       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 782         |
# |    ep_rew_mean          | 1.59        |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.001317132 |
# |    clip_fraction        | 0.00903     |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00899     |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.000418   |
# |    value_loss           | 0.0226      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 786           |
# |    ep_rew_mean          | 1.63          |
# | time/                   |               |
# |    fps                  | 414           |
# |    iterations           | 20            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00095317775 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.758         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0226        |
# |    n_updates            | 76            |
# |    policy_gradient_loss | -0.000551     |
# |    value_loss           | 0.0411        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 781          |
# |    ep_rew_mean          | 1.61         |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 21           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0029065649 |
# |    clip_fraction        | 0.0798       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.011        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.0347       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 773          |
# |    ep_rew_mean          | 1.56         |
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 22           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0036490303 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00816      |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 0.0255       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 789          |
# |    ep_rew_mean          | 1.68         |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 23           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0009825234 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.852        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0189       |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.000365    |
# |    value_loss           | 0.0341       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 800         |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 24          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003604128 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00336    |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | 1.64         |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 25           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0043306462 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0035       |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 0.0163       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 778          |
# |    ep_rew_mean          | 1.64         |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 26           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0017638172 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.000874    |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 794         |
# |    ep_rew_mean          | 1.73        |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 27          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.001231831 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0111      |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 0.0239      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 1.82         |
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 28           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0010373958 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00359      |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.0129       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 801          |
# |    ep_rew_mean          | 1.8          |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 29           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0023458009 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00545     |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 0.0165       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | 1.66         |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 30           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0030065556 |
# |    clip_fraction        | 0.082        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00306      |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 760          |
# |    ep_rew_mean          | 1.55         |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 31           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0020768503 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -5.78e-05    |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 0.00512      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 769          |
# |    ep_rew_mean          | 1.61         |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 32           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0012028762 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00084     |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 0.00737      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 769          |
# |    ep_rew_mean          | 1.59         |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 33           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0014578192 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0024       |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 0.00693      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 783          |
# |    ep_rew_mean          | 1.67         |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 34           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0021663562 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000503     |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 0.0113       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 774        |
# |    ep_rew_mean          | 1.62       |
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 35         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.00178746 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.00475    |
# |    n_updates            | 136        |
# |    policy_gradient_loss | -0.000891  |
# |    value_loss           | 0.00841    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 795          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 36           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0023837057 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00103     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 0.0104       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 37           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0032373497 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00603      |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 0.00794      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 827        |
# |    ep_rew_mean          | 1.95       |
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 38         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00238772 |
# |    clip_fraction        | 0.0723     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.00871    |
# |    n_updates            | 148        |
# |    policy_gradient_loss | -0.00158   |
# |    value_loss           | 0.0202     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 824          |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 39           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0030699363 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00954      |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000419    |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 839         |
# |    ep_rew_mean          | 2.05        |
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 40          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002901173 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00197    |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 0.0079      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 825          |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 41           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0018863279 |
# |    clip_fraction        | 0.0754       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000224     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 0.00667      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 811          |
# |    ep_rew_mean          | 1.84         |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 42           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0019635186 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00649     |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 43           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0034803848 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00038     |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 0.00204      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 814          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 44           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010373235 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00235     |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 0.00435      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 797         |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 45          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.002109257 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00383    |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 0.0137      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 46          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003034683 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.35e-05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 782          |
# |    ep_rew_mean          | 1.69         |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 47           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0009247968 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00183     |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 0.00787      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 792          |
# |    ep_rew_mean          | 1.77         |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 48           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0012795515 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000648     |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 0.00983      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | 1.69         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 49           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0020596331 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00163      |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.00959      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 787          |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 50           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0006065159 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00436      |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 795        |
# |    ep_rew_mean          | 1.78       |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 51         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 52224      |
# | train/                  |            |
# |    approx_kl            | 0.00377874 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0127    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0039    |
# |    value_loss           | 0.0104     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 779          |
# |    ep_rew_mean          | 1.68         |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 52           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014983214 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00341     |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.00585      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 1.56         |
# | time/                   |              |
# |    fps                  | 440          |
# |    iterations           | 53           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0029912451 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00824     |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 0.00472      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | 1.47        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 54          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.001034906 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00244    |
# |    n_updates            | 212         |
# ...
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 228          |
# |    time_elapsed         | 511          |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0034897856 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0101       |
# |    n_updates            | 908          |
# |    policy_gradient_loss | -0.00783     |
# |    value_loss           | 0.0613       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.82e+03     |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 229          |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 234496       |
# | train/                  |              |
# |    approx_kl            | 0.0026311344 |
# |    clip_fraction        | 0.082        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00944      |
# |    n_updates            | 912          |
# |    policy_gradient_loss | -0.00606     |
# |    value_loss           | 0.0513       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.83e+03     |
# |    ep_rew_mean          | 10.6         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 230          |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0034723603 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00983      |
# |    n_updates            | 916          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 0.054        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.83e+03     |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 231          |
# |    time_elapsed         | 516          |
# |    total_timesteps      | 236544       |
# | train/                  |              |
# |    approx_kl            | 0.0035238075 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00641      |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 0.0522       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.83e+03     |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 232          |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0025440773 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.705        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0155       |
# |    n_updates            | 924          |
# |    policy_gradient_loss | -0.00535     |
# |    value_loss           | 0.0688       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.85e+03    |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 233         |
# |    time_elapsed         | 522         |
# |    total_timesteps      | 238592      |
# | train/                  |             |
# |    approx_kl            | 0.003250075 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0115      |
# |    n_updates            | 928         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 0.0585      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+03    |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 234         |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 239616      |
# | train/                  |             |
# |    approx_kl            | 0.003805689 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0056      |
# |    n_updates            | 932         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 0.0461      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.83e+03     |
# |    ep_rew_mean          | 10.7         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 235          |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 240640       |
# | train/                  |              |
# |    approx_kl            | 0.0023041859 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00555      |
# |    n_updates            | 936          |
# |    policy_gradient_loss | -0.00755     |
# |    value_loss           | 0.0536       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.82e+03     |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 236          |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0031962893 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.749       |
# |    explained_variance   | 0.792        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000186     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00774     |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.84e+03     |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 237          |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 242688       |
# | train/                  |              |
# |    approx_kl            | 0.0025788764 |
# |    clip_fraction        | 0.0901       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0197       |
# |    n_updates            | 944          |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 0.0641       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.85e+03     |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 238          |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 243712       |
# | train/                  |              |
# |    approx_kl            | 0.0026460951 |
# |    clip_fraction        | 0.0984       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.748       |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0115       |
# |    n_updates            | 948          |
# |    policy_gradient_loss | -0.00704     |
# |    value_loss           | 0.0589       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.86e+03     |
# |    ep_rew_mean          | 11           |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 239          |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 244736       |
# | train/                  |              |
# |    approx_kl            | 0.0043998174 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00166     |
# |    n_updates            | 952          |
# |    policy_gradient_loss | -0.00851     |
# |    value_loss           | 0.048        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.85e+03     |
# |    ep_rew_mean          | 11.1         |
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 240          |
# |    time_elapsed         | 537          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0036080903 |
# |    clip_fraction        | 0.0854       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00641      |
# |    n_updates            | 956          |
# |    policy_gradient_loss | -0.00629     |
# |    value_loss           | 0.0466       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.85e+03    |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 241         |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 246784      |
# | train/                  |             |
# |    approx_kl            | 0.003172352 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0128      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00885    |
# |    value_loss           | 0.0736      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86e+03    |
# |    ep_rew_mean          | 11.2        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 242         |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 247808      |
# | train/                  |             |
# |    approx_kl            | 0.007166523 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00929     |
# |    n_updates            | 964         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 0.0652      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.88e+03     |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 243          |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 248832       |
# | train/                  |              |
# |    approx_kl            | 0.0048885597 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00521      |
# |    n_updates            | 968          |
# |    policy_gradient_loss | -0.00764     |
# |    value_loss           | 0.0556       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 244          |
# |    time_elapsed         | 544          |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0034836344 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00717      |
# |    n_updates            | 972          |
# |    policy_gradient_loss | -0.00602     |
# |    value_loss           | 0.0676       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 245          |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 250880       |
# | train/                  |              |
# |    approx_kl            | 0.0042756954 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000731     |
# |    n_updates            | 976          |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 0.0572       |
# ------------------------------------------

# %%
# # Get model path from last training job (uncomment if training job interrupted)
# # List all entries in the directory
# entries = os.listdir(training_data_path)

# # Filter out only directories
# folders = [entry for entry in entries if os.path.isdir(os.path.join(training_data_path, entry))]

# # Sort the folders alphabetically
# folders.sort()

# # Get the last folder
# model_folder_path = os.path.join(training_data_path, folders[-1])
# print(model_folder_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the Evaluation Atari's Pong environment with appropriate wrappers
env_val = make_atari_env(env_str,
                         n_envs=1,
                         seed=1)
env_val = VecFrameStack(env_val, n_stack=4)
env_val = VecTransposeImage(env_val)

# Load the best model
best_model_path = os.path.join(model_folder_path, "best_model")
best_model = PPO.load(best_model_path, env=env_val)

mean_reward, std_reward = evaluate_policy(
    best_model,
    env_val,
    n_eval_episodes=5)
print(f"Best Model - Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")

best_metrics_path = os.path.join(log_dir, "best_model_metrics.csv")

# Create Best Model Metrics file if not there
if(not os.path.isfile(best_metrics_path)):
  with open(best_metrics_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["run_date",
                     "batch_size",
                     "ent_coef",
                     "learning_rate",
                     "num_timesteps",
                     "mean_reward",
                     "std_reward",
                     "n_steps",
                     "n_envs",
                     "gamma",
                     "gae_lambda",
                     "clip_range_vf",
                     "n_epochs"])

new_data = [os.path.basename(os.path.normpath(model_folder_path)),
            best_model.batch_size,
            best_model.ent_coef,
            best_model.learning_rate,
            best_model.num_timesteps,
            mean_reward,
            std_reward,
            best_model.n_steps,
            best_model.n_envs,
            best_model.gamma,
            best_model.gae_lambda,
            best_model.clip_range_vf,
            best_model.n_epochs]

with open(best_metrics_path, 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(new_data)

# Record video of the best model playing Atari's Pong
rec_val = VecVideoRecorder(env_val,
                           os.path.join(model_folder_path, "videos"),
                           video_length=5000,
                           record_video_trigger=lambda x: x == 0,
                           name_prefix="best_model_{}".format(name_prefix))

obs = rec_val.reset()
for _ in range(5000):
    action, _states = best_model.predict(obs)
    obs, rewards, dones, info = rec_val.step(action)
    rec_val.render()
    if dones:
      break

env_val.close()
rec_val.close()
# Out:
# Best Model - Mean reward: 11.60 +/- 3.14
# Moviepy - Building video /content/gdrive/MyDrive/Finding Theta/logs/BreakoutNoFrameskip-v4/PPO/training jobs/2024-12-15 06:40:09/videos/best_model_atari_breakout_ppo-step-0-to-step-5000.mp4.
# Moviepy - Writing video /content/gdrive/MyDrive/Finding Theta/logs/BreakoutNoFrameskip-v4/PPO/training jobs/2024-12-15 06:40:09/videos/best_model_atari_breakout_ppo-step-0-to-step-5000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/gdrive/MyDrive/Finding Theta/logs/BreakoutNoFrameskip-v4/PPO/training jobs/2024-12-15 06:40:09/videos/best_model_atari_breakout_ppo-step-0-to-step-5000.mp4

# %%
# Print Model
print(best_model.policy)
# Out:
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential()
#     (value_net): Sequential()
#   )
#   (action_net): Linear(in_features=512, out_features=4, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
# Load the evaluations.npz file
data = numpy.load(os.path.join(model_folder_path, "evaluations.npz"))

# Extract the relevant data
timesteps = data['timesteps']
results = data['results']

# Calculate the mean and standard deviation of the results
mean_results = numpy.mean(results, axis=1)
std_results = numpy.std(results, axis=1)

# Plot the results
matplotlib.pyplot.figure()
matplotlib.pyplot.plot(timesteps, mean_results)
matplotlib.pyplot.fill_between(timesteps,
                               mean_results - std_results,
                               mean_results + std_results,
                               alpha=0.3)

matplotlib.pyplot.xlabel('Timesteps')
matplotlib.pyplot.ylabel('Mean Reward')
matplotlib.pyplot.title(f"{rl_type} Performance on {env_str}")
matplotlib.pyplot.show()
